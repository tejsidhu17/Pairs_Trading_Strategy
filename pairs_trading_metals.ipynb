# %%
import pairs_trading_strategy_lib as pts

tickers = ["CQQQ", "BABA", "BHP", "MT", "VALE", "FCX", "AA", "CNX", "COP", "HCC", "REMX", "CLF", "NEM", "GOLD", "LAC", "PLS.AX", "SQM", "600111.SS", "600549.SS"]
data = pts.get_historical_data(tickers, "1y")
pts.create_correlation_heatmap(data)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
pairs = [("NEM", "GOLD"), ("PLS.AX", "SQM"), ("CLF", "NEM"), ("AA", "FCX"), ("BHP", "MT"), ("VALE", "MT"), ("600111.SS", "LAC"), ("HCC", "FCX")]
for pair in pairs:
    pts.plot_ratio(data, pair)

# %%
for pair in pairs:
    pts.plot_spreads(data, pair)

# %%
# Fix missing data error
good_pairs = [("AA", "FCX"), ("BHP", "MT"), ("PLS.AX", "SQM")]
for pair in good_pairs:
    pts.cointegration_test(data, pair)
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# Cell In[4], line 4
#       2 good_pairs = [("AA", "FCX"), ("BHP", "MT"), ("PLS.AX", "SQM")]
#       3 for pair in good_pairs:
# ----> 4     pts.cointegration_test(data, pair)
#
# File ~/Projects/Pairs_Trading_Strategy/pairs_trading_strategy_lib.py:46, in cointegration_test(data, tuple)
#      45 def cointegration_test(data, tuple):
# ---> 46     engle_granger_p_val = (ts.coint(data[tuple[0]], data[tuple[1]]))[1]
#      47     spread_adf_p_val = (adfuller(data[tuple[0]] - data[tuple[1]]))[1]
#      48     ratio_adf_p_val = (adfuller(data[tuple[0]]/data[tuple[1]]))[1]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1814, in coint(y0, y1, trend, method, maxlag, autolag, return_results)
#    1811 else:
#    1812     xx = add_trend(y1, trend=trend, prepend=False)
# ...
