# %%
import yfinance as yf
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import statsmodels.tsa.stattools as ts
from statsmodels.tsa.stattools import adfuller
import pairs_trading_strategy_lib as pts

tickers = ["INTC", "AMD", "NVDA", "SMCI", "CQQQ", "INQQ", "EMQQ", "VALE", "FCX", "BABA", "BIDU", "LYFT", "UBER", "JD", "NEM", "BHP", "MT"]
data = pts.get_historical_data(tickers, "1y")
pts.create_correlation_heatmap(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
pair = ("AMD", "UBER")
ratio = pts.plot_ratio(data, pair)

# %%
spread = pts.plot_spreads(data, pair)

# %%
pts.cointegration_test(data, pair)
# Out:
# Engle Granger Test: 0.10377073679862264
# AD Fuller Test Spread: 0.1667329350942805
# AD Fuller Test Ratio: 0.024579017741945954

# %%
pts.plot_ratio(data, pair)
# Out:
# 2023-09-28    2.227135
# 2023-09-29    2.235703
# 2023-10-02    2.260727
# 2023-10-03    2.248484
# 2023-10-04    2.315754
#                 ...
# 2024-09-23    2.098113
# 2024-09-24    2.044422
# 2024-09-25    2.100337
# 2024-09-26    2.183987
# 2024-09-27    2.169637
# Length: 252, dtype: float64

# %%
pts.plot_spreads(data, pair)
# Out:
# 2023-09-28    56.620003
# 2023-09-29    56.829998
# 2023-10-02    57.589996
# 2023-10-03    55.570004
# 2023-10-04    59.130001
#                 ...
# 2024-09-23    82.040001
# 2024-09-24    80.880005
# 2024-09-25    84.880005
# 2024-09-26    90.800003
# 2024-09-27    88.600006
# Length: 252, dtype: float64

# %%
z_score = pts.plot_zscore(ratio, [-1, -1.25, 2, 1.25], pair)

# %%
pts.develop_strategy(ratio, "Ratio", z_score, -1, 1, pair)
