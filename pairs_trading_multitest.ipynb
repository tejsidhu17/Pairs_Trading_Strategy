# %%
import pairs_trading_strategy_lib as pts

tickers = ["INTC", "AMD", "NVDA", "SMCI", "CQQQ", "INQQ", "EMQQ", "VALE", "FCX", "BABA", "BIDU", "LYFT", "UBER", "JD", "NEM", "BHP", "MT"]
data = pts.get_historical_data(tickers, "1y")
pts.create_correlation_heatmap(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
pair = ("AMD", "UBER")
ratio = pts.plot_ratio(data, pair)

# %%
spread = pts.plot_spreads(data, pair)

# %%
pts.cointegration_test(data, pair)
# Out:
# Engle Granger Test: 0.2003112856876446
# AD Fuller Test Spread: 0.09123742953434599
# AD Fuller Test Ratio: 0.06224248238867271

# %%
pts.plot_ratio(data, pair)
# Out:
# 2023-11-09    2.267532
# 2023-11-10    2.299147
# 2023-11-13    2.235643
# 2023-11-14    2.224944
# 2023-11-15    2.194941
#                 ...
# 2024-11-04    1.920956
# 2024-11-05    1.910452
# 2024-11-06    1.951318
# 2024-11-07    2.048681
# 2024-11-08    2.053720
# Length: 252, dtype: float64

# %%
pts.plot_spreads(data, pair)
# Out:
# 2023-11-09    63.439999
# 2023-11-10    67.009995
# 2023-11-13    64.549999
# 2023-11-14    65.999996
# 2023-11-15    64.240002
#                 ...
# 2024-11-04    67.460007
# 2024-11-05    67.510002
# 2024-11-06    70.740005
# 2024-11-07    76.690010
# 2024-11-08    75.909996
# Length: 252, dtype: float64

# %%
z_score = pts.plot_zscore(ratio, [-1, -1.25, 2, 1.25], pair)

# %%
pts.develop_strategy(ratio, "Ratio", z_score, -1, 1, pair)
